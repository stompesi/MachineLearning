# %%
import demo

# %%
demo.run()
# Out:
# <DecisionTree>
#   <졸업여부 flag="m" p="0.097" value="졸업">
#     <연령대 flag="l" p="0.391" value="30.0">
#       <회차 flag="l" p="0.016" value="53.0">
#         <성별 flag="m" p="0.65" value="남">불합격</성별>
#         <성별 flag="m" p="0.35" value="여">불합격</성별>
#       </회차>
#       <회차 flag="r" p="0.984" value="53.0">
#         <연도 flag="l" p="0.019" value="2001.0">
#           <성별 flag="m" p="0.766" value="남">합격</성별>
#           <성별 flag="m" p="0.234" value="여">합격</성별>
#         </연도>
#         <연도 flag="r" p="0.981" value="2001.0">
#           <회차 flag="l" p="0.059" value="56.0">
#             <연도 flag="l" p="0.457" value="2002.0">
#               <성별 flag="m" p="0.766" value="남">합격</성별>
#               <성별 flag="m" p="0.234" value="여">합격</성별>
#             </연도>
#             <연도 flag="r" p="0.543" value="2002.0">
#               <성별 flag="m" p="0.711" value="남">
#                 <연도 flag="l" p="0.407" value="2003.0">불합격</연도>
#                 <연도 flag="r" p="0.593" value="2003.0">불합격</연도>
# ...

# %%
a ={'a':1}

# %%
'a' in a
